# %%
# !pip install git+https://github.com/tweepy/tweepy.git
#Version 2.0
# !pip install tweepy --upgrade
# Out:
# ...
#   Cloning https://github.com/tweepy/tweepy.git to c:\users\oliva\appdata\local\temp\pip-req-build-bqgek9cd
#   Resolved https://github.com/tweepy/tweepy.git to commit 51c37626b76b40693cc033fec7c71d56090f7135
# ...
#   Running command git clone -q https://github.com/tweepy/tweepy.git 'C:\Users\oliva\AppData\Local\Temp\pip-req-build-bqgek9cd'
# ...

# %%
import tweepy

#Autenticación de datos

api_key = "Z5TyWo6TPz4pUenlUyYlyHLSK"
api_secret_key = "5llBbqj9ZMj1FtyKnNWS9KfF0OJ0lFJ0ixcT9sXZhcatqH1IRl"
access_token = "1543237496988995584-RSNOAgXCkeQUQTRuxHqCRLiTL2Fv7N"
access_token_secret = "w5hppAyNH5XZWAOPFFP4KIsWcIytJKz7aIIlZJMkBf4z3"

auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAAaYfwEAAAAAyPym2NF3kvS5vl20uGyKAgEshm0%3DM5PQro5gAZvb6tQzKQRqyZkBkIi3xThwBJJyHaC2YtvnQw2lgj')

# Replace with your own search query
#query = 'from:suhemparack -is:retweet'
#"https://twitter.com/search?q=(devaluacion%20OR%20devaluaci%C3%B3n)%20(from%3Aclarincom)%20min_faves%3A20%20-filter%3Areplies&src=typed_query"
query = "(devaluacion OR dolar) from:clarincom -is:retweet"

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# El nuevo cepo para el dólar soja: ¿traición y avivada de los productores contra el Gobierno? https://t.co/v6PfsjgDXT
# [{'domain': {'id': '69', 'name': 'News Vertical', 'description': 'News Categories like Entertainment or Technology'}, 'entity': {'id': '1192886471100731392', 'name': 'Argentina national news'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy view into the Semantic Core knowledge graph'}, 'entity': {'id': '1192886471100731392', 'name': 'Argentina national news'}}, {'domain': {'id': '69', 'name': 'News Vertical', 'description': 'News Categories like Entertainment or Technology'}, 'entity': {'id': '1192886471100731392', 'name': 'Argentina national news'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy view into the Semantic Core knowledge graph'}, 'entity': {'id': '1192886471100731392', 'name': 'Argentina national news'}}]
# ...

# %%
# Replace with your own search query
query = 'covid -is:retweet'

# Replace with your own search query
query = 'covid -is:retweet'

# Name and path of the file where you want the Tweets written to
file_name = 'tweets.txt'

with open(file_name, 'a+') as filehandle:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                                  tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(
            limit=1000):
        filehandle.write(tweet.encode(sys.stdout.encoding, errors='replace'))
     #   filehandle.write('%s\n' % tweet.id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17920/2684683677.py in <module>
#      12                                   tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(
#      13             limit=1000):
# ---> 14         filehandle.write(tweet.encode(sys.stdout.encoding, errors='replace'))
#      15      #   filehandle.write('%s\n' % tweet.id)
#
# ~\anaconda3\lib\site-packages\tweepy\mixins.py in __getattr__(self, name)
#      33             return self.data[name]
#      34         except KeyError:
# ---> 35             raise AttributeError from None
#      36
#      37     def __getitem__(self, key):
#
# AttributeError:

# %%
# Replace with your own search query
query = 'covid -is:retweet'

# Replace the limit=1000 with the maximum number of Tweets you want
for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                              tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=1):
    print(tweet.text)
    
type(tweet.text)
# Out:
# More people are dying domestically from Covid every week than the number of people who died from HIV during its deadliest year.
#
# Just because something is normal doesn't mean it's okay.
# str

# %%
twitter.com/anyuser/status/1573022496227459073
# Out:
# 'UTF-8'
