# %%
pip install git+https://github.com/tweepy/tweepy.git
#Version 2.0
# !pip install tweepy --upgrade
# Out:
# ...
#   Cloning https://github.com/tweepy/tweepy.git to c:\users\oliva\appdata\local\temp\pip-req-build-94gsxxuo
#   Resolved https://github.com/tweepy/tweepy.git to commit 4f28bd85d85adf0fb735a3e24b45e7804c534aa7
# ...
#   Created wheel for tweepy: filename=tweepy-4.10.1-py3-none-any.whl size=95327 sha256=d030416d40862fb2fba39fb0b898a05ff1c92215cdb9c7dde3dd1b3bf7d05570
#   Stored in directory: C:\Users\oliva\AppData\Local\Temp\pip-ephem-wheel-cache-e8udnnz7\wheels\37\db\50\af7b44cc37a83332e50fbebe7290974b5f463e294dbc4eeaf8
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/tweepy/tweepy.git 'C:\Users\oliva\AppData\Local\Temp\pip-req-build-94gsxxuo'
# Successfully built tweepy
# ...
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.10.0
#     Uninstalling tweepy-4.10.0:
#       Successfully uninstalled tweepy-4.10.0
# ...

# %%
import tweepy

#Autenticación de datos

consumer_key = "MNQh3XeTunDHKL0yTVxquMA9H"
consumer_secret = "nmH6WU5J2nBOW0izqzyp35ekpcPfoemrM7Gzn27XXTptw6KZXb"
access_token = "1543237496988995584-v0mjHbjpdmeof682DCCEYgpftZQu3W"
access_token_secret = "pgAdvbdYay6hdfPVCi2PukWdm29vnhO8mI4QBUMpz8E0X"

auth = tweepy.OAuth1UserHandler(
   consumer_key, consumer_secret, access_token, access_token_secret
)

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAAaYfwEAAAAAcCONDyYMkZnTrZK7AwDAwOl4h80%3DEwoz22rXFFmbJ38lFJsTHUpAmiRNtznba5lgOhUizw8NsNMjeB')

# Replace with your own search query
#query = 'from:suhemparack -is:retweet'
query = "Austral"

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# RT @CRUCH_cl: 🔵Respecto a la violencia escolar, el rector de  @UFrontera, @EduardoHebel, plantea que “es necesario hacer un esfuerzo país p…
# RT @funesbeto: Internaron a Esteban Bullrich en el Hospital Austral por una descompensación. El ex senador tiene Esclerosis Lateral Amiotró…
# ...
